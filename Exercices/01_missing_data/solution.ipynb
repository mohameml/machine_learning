# %%
# missing data :

import numpy as np 
import pandas as pd 
from sklearn.impute import SimpleImputer
import missingno as ms

data = pd.read_csv("data.csv")
X = data.values 

missing_data = data.isnull()
print(missing_data.sum())

# visualisation des missing data : 
ms.matrix(data)
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64
# <Axes: >
